# %%
import google.generativeai as genai
import gradio as gr

# Configure API key
genai.configure(api_key="AIzaSyDM1NuGAApez9lkYw9HNHXq1wfTVGyugvU")  # Replace with your actual Gemini API key

# Load the model
model = genai.GenerativeModel(model_name="gemini-3-flash-preview")

# System message (used only for context)
system_msg = "You are a financial expert specializing in real estate investment and negotiation."

# Chatbot function
def CustomGemini(user_input):
    response = model.generate_content(system_msg + "\n" + user_input)
    return response.text  # Extract and return response

# Gradio Interface
demo = gr.Interface(fn=CustomGemini, 
                    inputs="text", 
                    outputs="text", 
                    title="My Saving Assistant")

# Launch the app
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * Running on public URL: https://8f344381a3b27a9911.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://8f344381a3b27a9911.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
